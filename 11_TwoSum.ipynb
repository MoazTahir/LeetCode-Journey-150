# %%
from typing import List

# %%
def twoSum(nums: List[int], target: int) -> List[int]:
    lookup = {}
    for i, num in enumerate(nums):
        complement = target - num
        print("Complement: ", complement)
        if complement in lookup:
            print("Complement found in lookup: ", complement)
            return [lookup[complement], i]
        print("Adding to lookup: ", num, " at index ", i)
        lookup[num] = i

# %%
twoSum([2, 7, 11, 15], 9)
# Out:
# Complement:  7
# Adding to lookup:  2  at index  0
# Complement:  2
# Complement found in lookup:  2
# [0, 1]
